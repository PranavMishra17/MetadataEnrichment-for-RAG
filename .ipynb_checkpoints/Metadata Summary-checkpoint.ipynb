# %%
import json
import os
import time
from pathlib import Path
from typing import Dict, Any
from tqdm import tqdm
import logging
from langchain_openai import AzureChatOpenAI

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('json_processing.log'),
        logging.StreamHandler()
    ]
)

class ChunkProcessor:
    def __init__(self, input_dir: str, output_dir: str, batch_size: int = 5, delay: float = 1.0):
        self.input_dir = Path(input_dir)
        self.output_dir = Path(output_dir)
        self.batch_size = batch_size
        self.delay = delay
        self.output_dir.mkdir(exist_ok=True)
        
        # Initialize LLM
        self.llm = AzureChatOpenAI(
            azure_deployment="gpt-4o",
            azure_endpoint="https://vareopenai.openai.azure.com/",
            openai_api_key="D77yZjqWYmJ5i4buRg18iOQy72WebD8YiMadSUYTzJP0UsBPuN0JJQQJ99BBACYeBjFXJ3w3AAABACOG5PZg",
            api_version="2024-08-01-preview",
            verbose=False,
            temperature=1,
        )

    def get_summary(self, content: str) -> str:
        """Get one-line summary from LLM"""
        try:
            prompt = f"Summarize the following text in one concise line:\n\n{content}"
            response = self.llm.invoke(prompt)
            return response.content.strip()
        except Exception as e:
            logging.error(f"Error getting summary: {str(e)}")
            return None

    def process_file(self, file_path: Path):
        """Process a single JSON file"""
        #logging.info(f"Processing file: {file_path}")
        
        # Read input JSON
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
            
        output_file = self.output_dir / file_path.name
        
        # Load existing progress if any
        existing_data = {}
        if output_file.exists():
            with open(output_file, 'r', encoding='utf-8') as f:
                existing_data = json.load(f)

        # Process chunks in batches
        chunks_to_process = []
        for chunk in data['chunks']:
            # Skip if chunk already has summary
            if (existing_data and 
                'chunks' in existing_data and 
                any(ec['id'] == chunk['id'] and 'summary' in ec for ec in existing_data['chunks'])):
                continue
            chunks_to_process.append(chunk)

        if not chunks_to_process:
            logging.info(f"All chunks in {file_path.name} already processed")
            return

        for i in range(0, len(chunks_to_process), self.batch_size):
            batch = chunks_to_process[i:i + self.batch_size]
            
            for chunk in batch:
                #logging.info(f"Processing chunk {chunk['id']}")
                summary = self.get_summary(chunk['content'])
                if summary:
                    chunk['summary'] = summary
                else:
                    logging.warning(f"Failed to get summary for chunk {chunk['id']}")

            # Update existing data with new summaries
            if not existing_data:
                existing_data = data.copy()
            
            # Save progress after each batch
            with open(output_file, 'w', encoding='utf-8') as f:
                json.dump(existing_data, f, indent=2)

            logging.info(f"Saved progress after batch. Sleeping for {self.delay} seconds...")
            time.sleep(self.delay)

    def process_all_files(self):
        """Process all JSON files in the input directory"""
        for file_path in self.input_dir.glob('*.json'):
            try:
                self.process_file(file_path)
            except Exception as e:
                logging.error(f"Error processing {file_path}: {str(e)}")
                continue

# %%
import os
from pathlib import Path

# Get current directory
current_dir = Path(os.getcwd())

# Create directories
input_dir = current_dir / "_NEW CHUNKS"
output_dir = current_dir / "_COMPLETE CHUNKS"

input_dir.mkdir(exist_ok=True)
output_dir.mkdir(exist_ok=True)

# Initialize processor
processor = ChunkProcessor(input_dir, output_dir, batch_size=5, delay=1.0)

# Process files
processor.process_all_files()
# Out:
# 2025-02-18 22:20:55,496 - INFO - Processing file: C:\Users\prana\Desktop\Metadata enrichment with LLM\MetadataEnrichment-for-RAG\_NEW CHUNKS\NEW-glacier-dg-chunks.json
# 2025-02-18 22:20:55,591 - INFO - Processing chunk chunk_1
# 2025-02-18 22:20:57,483 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-18 22
- INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:41,822 - INFO - Processing chunk chunk_2458
# 2025-02-19 00:43:42,629 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:42,633 - INFO - Processing chunk chunk_2459
# 2025-02-19 00:43:43,582 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:43,592 - INFO - Processing chunk chunk_2460
# 2025-02-19 00:43:44,434 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:45,116 - INFO - Saved progress after batch. Sleeping for 1.0 seconds...
# 2025-02-19 00:43:46,118 - INFO - Processing chunk chunk_2461
# 2025-02-19 00:43:48,683 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:48,685 - INFO - Processing chunk chunk_2462
# 2025-02-19 00:43:49,443 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:49,446 - INFO - Processing chunk chunk_2463
# 2025-02-19 00:43:50,022 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:50,027 - INFO - Processing chunk chunk_2464
# 2025-02-19 00:43:50,847 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:50,850 - INFO - Processing chunk chunk_2465
# 2025-02-19 00:43:55,532 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:56,363 - INFO - Saved progress after batch. Sleeping for 1.0 seconds...
# 2025-02-19 00:43:57,365 - INFO - Processing chunk chunk_2466
# 2025-02-19 00:43:58,750 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:58,756 - INFO - Processing chunk chunk_2467
# 2025-02-19 00:43:59,610 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:43:59,614 - INFO - Processing chunk chunk_2468
# 2025-02-19 00:44:00,546 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:00,550 - INFO - Processing chunk chunk_2469
# 2025-02-19 00:44:01,847 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:01,851 - INFO - Processing chunk chunk_2470
# 2025-02-19 00:44:02,599 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:03,471 - INFO - Saved progress after batch. Sleeping for 1.0 seconds...
# 2025-02-19 00:44:04,472 - INFO - Processing chunk chunk_2471
# 2025-02-19 00:44:05,387 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:05,391 - INFO - Processing chunk chunk_2472
# 2025-02-19 00:44:06,399 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:06,401 - INFO - Processing chunk chunk_2473
# 2025-02-19 00:44:07,077 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:07,079 - INFO - Processing chunk chunk_2474
# 2025-02-19 00:44:07,761 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:07,763 - INFO - Processing chunk chunk_2475
# 2025-02-19 00:44:08,297 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:08,890 - INFO - Saved progress after batch. Sleeping for 1.0 seconds...
# 2025-02-19 00:44:09,891 - INFO - Processing chunk chunk_2476
# 2025-02-19 00:44:11,210 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:11,214 - INFO - Processing chunk chunk_2477
# 2025-02-19 00:44:12,448 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:12,452 - INFO - Processing chunk chunk_2478
# 2025-02-19 00:44:13,273 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:13,276 - INFO - Processing chunk chunk_2479
# 2025-02-19 00:44:14,264 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:14,268 - INFO - Processing chunk chunk_2480
# 2025-02-19 00:44:14,915 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:15,475 - INFO - Saved progress after batch. Sleeping for 1.0 seconds...
# 2025-02-19 00:44:16,477 - INFO - Processing chunk chunk_2481
# 2025-02-19 00:44:17,071 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:17,076 - INFO - Processing chunk chunk_2482
# 2025-02-19 00:44:18,696 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:18,700 - INFO - Processing chunk chunk_2483
# 2025-02-19 00:44:19,461 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:19,463 - INFO - Processing chunk chunk_2484
# 2025-02-19 00:44:20,393 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:20,395 - INFO - Processing chunk chunk_2485
# 2025-02-19 00:44:21,292 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:21,793 - INFO - Saved progress after batch. Sleeping for 1.0 seconds...
# 2025-02-19 00:44:22,795 - INFO - Processing chunk chunk_2486
# 2025-02-19 00:44:23,427 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:23,431 - INFO - Processing chunk chunk_2487
# 2025-02-19 00:44:24,075 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:24,079 - INFO - Processing chunk chunk_2488
# 2025-02-19 00:44:24,712 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:24,715 - INFO - Processing chunk chunk_2489
# 2025-02-19 00:44:25,999 - INFO - HTTP Request: POST https://vareopenai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# 2025-02-19 00:44:26,517 - INFO - Saved progress after batch. Sleeping for 1.0 seconds...

# %% [markdown]
# # Chunk Hierarchy Processor

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------- ----------------------------- 3.4/12.8 MB 25.2 MB/s eta 0:00:01
#      ------------------------- -------------- 8.1/12.8 MB 22.9 MB/s eta 0:00:01
#      ------------------------------------ -- 12.1/12.8 MB 21.6 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\prana\anaconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10.6)
# Requirement already satisfied: jinja2 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.8.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\prana\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\prana\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prana\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\prana\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\prana\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prana\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prana\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prana\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prana\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\prana\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\prana\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\prana\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\prana\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\prana\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\prana\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.8.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\prana\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\prana\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\prana\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\prana\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\prana\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\prana\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\prana\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.0)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# WARNING: Ignoring invalid distribution ~illow (C:\Users\prana\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~rotobuf (C:\Users\prana\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yarrow (C:\Users\prana\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~illow (C:\Users\prana\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~rotobuf (C:\Users\prana\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yarrow (C:\Users\prana\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~illow (C:\Users\prana\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~rotobuf (C:\Users\prana\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yarrow (C:\Users\prana\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
import spacy
from pathlib import Path
import logging
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from tqdm import tqdm

class HierarchyProcessor:
    def __init__(self, input_dir: str):
        self.input_dir = Path(input_dir)
        self.nlp = spacy.load("en_core_web_sm")
        
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s'
        )

    def get_embedding(self, text):
        doc = self.nlp(text)
        return doc.vector

    def analyze_hierarchy(self, chunks):
        embeddings = np.array([self.get_embedding(chunk['content']) for chunk in chunks])
        similarities = cosine_similarity(embeddings)

        for i, chunk in enumerate(chunks):
            chunk['parent'] = []
            chunk['children'] = []

            # Find top 3 parents (from previous chunks)
            if i > 0:
                prev_similarities = similarities[i, :i]
                top_parents = np.argsort(prev_similarities)[-3:]
                for parent_idx in top_parents:
                    if similarities[i, parent_idx] > 0.6:  # Minimum threshold
                        chunk['parent'].append(chunks[parent_idx]['id'])

            # Find top 3 children (from subsequent chunks)
            if i < len(chunks) - 1:
                next_similarities = similarities[i, i+1:]
                top_children = np.argsort(next_similarities)[-3:]
                for child_idx in top_children:
                    actual_idx = child_idx + i + 1
                    if similarities[i, actual_idx] > 0.6:
                        chunk['children'].append(chunks[actual_idx]['id'])

        return chunks

    def process_file(self, file_path):
        logging.info(f"Processing {file_path}")
        
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        # Process chunks
        data['chunks'] = self.analyze_hierarchy(data['chunks'])
        
        # Save updated file
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=2)

    def process_all_files(self):
        for file_path in tqdm(list(self.input_dir.glob('*.json'))):
            try:
                self.process_file(file_path)
            except Exception as e:
                logging.error(f"Error processing {file_path}: {str(e)}")

# %%
# Usage in Jupyter notebook:
input_dir = Path(os.getcwd()) / "_COMPLETE CHUNKS"
processor = HierarchyProcessor(input_dir)
processor.process_all_files()
# Out:
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]2025-02-19 00:52:23,795 - INFO - Processing C:\Users\prana\Desktop\Metadata enrichment with LLM\MetadataEnrichment-for-RAG\_COMPLETE CHUNKS\NEW-glacier-dg-chunks.json
#  25%|█████████████████████                                                               | 1/4 [00:26<01:18, 26.29s/it]2025-02-19 00:52:50,083 - INFO - Processing C:\Users\prana\Desktop\Metadata enrichment with LLM\MetadataEnrichment-for-RAG\_COMPLETE CHUNKS\NEW-s3-api-chunks.json
#  50%|██████████████████████████████████████████                                          | 2/4 [02:49<03:10, 95.26s/it]2025-02-19 00:55:13,629 - INFO - Processing C:\Users\prana\Desktop\Metadata enrichment with LLM\MetadataEnrichment-for-RAG\_COMPLETE CHUNKS\NEW-s3-outposts-chunks.json
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [03:01<00:56, 56.92s/it]2025-02-19 00:55:24,929 - INFO - Processing C:\Users\prana\Desktop\Metadata enrichment with LLM\MetadataEnrichment-for-RAG\_COMPLETE CHUNKS\NEW-s3-userguide-chunks.json
